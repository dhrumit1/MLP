# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'D:\dhrumit\sem2\MLP\cars.csv')

# %%
df
# Out:
#      Unnamed: 0  price      brand     model  year   title_status  mileage  \
# 0             0   6300     toyota   cruiser  2008  clean vehicle   274117
# 1             1   2899       ford        se  2011  clean vehicle   190552
# 2             2   5350      dodge       mpv  2018  clean vehicle    39590
# 3             3  25000       ford      door  2014  clean vehicle    64146
# 4             4  27700  chevrolet      1500  2018  clean vehicle     6654
# 5             5   5700      dodge       mpv  2018  clean vehicle    45561
# 6             6   7300  chevrolet        pk  2010  clean vehicle   149050
# 7             7  13350        gmc      door  2017  clean vehicle    23525
# 8             8  14600  chevrolet    malibu  2018  clean vehicle     9371
# 9             9   5250       ford       mpv  2017  clean vehicle    63418
# 10           10  10400      dodge     coupe  2009  clean vehicle   107856
# 11           11  12920        gmc       mpv  2017  clean vehicle    39650
# ...

# %%
df1 = df[['brand','model','year','mileage','color','condition','price']]
df1
# Out:
#          brand     model  year  mileage   color      condition  price
# 0       toyota   cruiser  2008   274117   black   10 days left   6300
# 1         ford        se  2011   190552  silver    6 days left   2899
# 2        dodge       mpv  2018    39590  silver    2 days left   5350
# 3         ford      door  2014    64146    blue  22 hours left  25000
# 4    chevrolet      1500  2018     6654     red  22 hours left  27700
# 5        dodge       mpv  2018    45561   white    2 days left   5700
# 6    chevrolet        pk  2010   149050   black  22 hours left   7300
# 7          gmc      door  2017    23525    gray  20 hours left  13350
# 8    chevrolet    malibu  2018     9371  silver  22 hours left  14600
# 9         ford       mpv  2017    63418   black    2 days left   5250
# 10       dodge     coupe  2009   107856  orange  22 hours left  10400
# 11         gmc       mpv  2017    39650   white  20 hours left  12920
# ...

# %%
x= df1.iloc[:,:6]

# %%
y=df1.iloc[:,6]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
x['brand'] = le.fit_transform(x['brand'])

# %%
x['model'] = le.fit_transform(x['model'])

# %%
x['year'] = le.fit_transform(x['year'])

# %%
x['mileage'] = le.fit_transform(x['mileage'])

# %%
x['color'] = le.fit_transform(x['color'])

# %%
x['condition'] = le.fit_transform(x['condition'])
x
# Out:
#      brand  model  year  mileage  color  condition  price
# 0       12     14     2      175      1          1     26
# 1        6     38     5      173     10         14      1
# 2        5     34    11      102     10          6     16
# 3        6     17     7      148      2         10    112
# 4        3      0    11        3      9         10    121
# 5        5     34    11      119     12          6     21
# 6        3     36     4      170      1         10     38
# 7        7     17    10       26      6          8     60
# 8        3     33    11        5     10         10     64
# 9        6     34    10      147      1          6     14
# 10       5     13     3      164      8         10     48
# 11       7     34    10      103     12          8     57
# 12       3      0    11       24      1         10    131
# 13       4     44    10      169      6          6     17
# 14       6     17     6      162      1         10     94
# ...

# %%
y = le.fit_transform(y)

# %%
y
# Out:
# array([ 26,   1,  16, 112, 121,  21,  38,  60,  64,  14,  48,  57, 131,
#         17,  94,  55,  12,  72,  13, 138,  54,  38,  66,  25,  95,  52,
#         99,  53,   5,  58,  55,  81, 127,  15,  58,  52,  73,  85,  39,
#         35,  55,  73, 128,  27, 146,  54,  71,  83,  19, 145,  55,  70,
#        120,  41,  90,  57,  92,  79, 102,  81,  61,  94,  75,  29, 125,
#         55,  98,  82,   8,  86,  56,  68, 126,   9,  87,  54,  69, 116,
#          3,  80,  54,  76,  80,  10, 107,  59,  77,  65,   3,  51,  45,
#         40, 109,  47, 140, 144,  67, 135, 119,  22,  62, 106,  49,  63,
#        113,  36,  44,  78,  43, 103, 109,  35,  74, 136,  34, 112,  96,
#         46, 118, 111,  36, 123, 142, 104, 105,  50, 133, 143,  33,  52,
#        117,   4,  88,  20, 115, 108,  11,  89, 132,  32,   6,   0, 130,
#         37,   0, 122,  32, 134,  49,  30,  92,  28,  91, 137,   2, 100,
#        129,   7, 101,  84,   4,  81, 139,  23, 124, 141,  24,  97,  93,
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (123, 7)

# %%
y_train.shape
# Out:
# (123,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lin_model = LogisticRegression()

# %%
lin_model
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
lin_model.fit(x_train,y_train)
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Dell\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred = lin_model.predict(x_test)
y_pred
# Out:
# array([ 55, 100,  49,  48,  49,  55,  53, 138,  52,  88, 139,  80,  51,
#         54,  55,   0, 118,  55,  55,  77,  16, 139,  55,  92,  14,  92,
#         47,  25, 131,  48,  24,  64,  55, 112,  55,  92, 137,  65, 134,
#        109,  24,  64,  84,  40, 132,  87, 116,  52,   6,  14, 125,  42,
#        140, 105], dtype=int64)

# %%
y_test
# Out:
# array([ 52, 104,  35,  58,  36,  57,  75, 145,  46,  82, 141,  81,  43,
#         56,  55,   1, 146, 112,  63,  98,  19, 144,   8,  26,  18,  69,
#         50,  22, 143,  58,  32,  74,  35, 107,  97,  52, 109,  85, 129,
#        113,  31,  38,  79,  66, 136, 128, 130,  54,  11,  17, 133,   5,
#        121,  93], dtype=int64)

# %%
lin_model.score(x_test,y_test)
# Out:
# 0.018518518518518517

# %%
lin_model.predict([[5,10,20,10,5,6,8]])
# Out:
# array([28], dtype=int64)
