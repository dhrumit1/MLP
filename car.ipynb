# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
car=pd.read_csv("cars.csv")
car
# Out:
#      Unnamed: 0  price      brand     model  year   title_status  mileage  \
# 0             0   6300     toyota   cruiser  2008  clean vehicle   274117
# 1             1   2899       ford        se  2011  clean vehicle   190552
# 2             2   5350      dodge       mpv  2018  clean vehicle    39590
# 3             3  25000       ford      door  2014  clean vehicle    64146
# 4             4  27700  chevrolet      1500  2018  clean vehicle     6654
# 5             5   5700      dodge       mpv  2018  clean vehicle    45561
# 6             6   7300  chevrolet        pk  2010  clean vehicle   149050
# 7             7  13350        gmc      door  2017  clean vehicle    23525
# 8             8  14600  chevrolet    malibu  2018  clean vehicle     9371
# 9             9   5250       ford       mpv  2017  clean vehicle    63418
# 10           10  10400      dodge     coupe  2009  clean vehicle   107856
# 11           11  12920        gmc       mpv  2017  clean vehicle    39650
# ...

# %%
car.tail()
# Out:
#      Unnamed: 0  price      brand model  year   title_status  mileage  color  \
# 172         172   5470      dodge   mpv  2018  clean vehicle    39721  black
# 173         173  14600       ford  door  2014  clean vehicle    75785  black
# 174         174  24502  chevrolet  1500  2016  clean vehicle    33624  black
# 175         175  15110       ford  door  2017  clean vehicle    42289  white
# 176         176   7900       ford  door  2014  clean vehicle    79422  white
#
#                      vin        lot         state country      condition
# 172    3c4pdcgg9jt216280  167656495       florida     usa  16 hours left
# 173    1fm5k8f81egb23411  167756284  pennsylvania     usa  21 hours left
# 174    3gcuknec6gg150809  167765812      michigan     usa  20 hours left
# 175    1ft7w2bt7hec67263  167656516         texas     usa    2 days left
# 176    1fmcu0g9xeud52262  167756290      new york     usa  21 hours left

# %%
car.shape
# Out:
# (177, 13)

# %%
car.size
# Out:
# 2301

# %%
c=car[["brand","price"]]
c
# Out:
#          brand  price
# 0       toyota   6300
# 1         ford   2899
# 2        dodge   5350
# 3         ford  25000
# 4    chevrolet  27700
# 5        dodge   5700
# 6    chevrolet   7300
# 7          gmc  13350
# 8    chevrolet  14600
# 9         ford   5250
# 10       dodge  10400
# 11         gmc  12920
# 12   chevrolet  31900
# 13    chrysler   5430
# 14        ford  20700
# 15         gmc  12710
# 16         kia   5200
# 17       buick  16500
# 18        ford   5210
# 19        ford  38100
# 20         gmc  12520
# 21         kia   7300
# 22   chevrolet  15000
# 23        ford   6180
# 24        ford  20800
# 25         gmc  11900
# 26         kia  21500
# 27       buick  12000
# 28        ford   4190
# 29        ford  13000
# ..         ...    ...
# 147   cadillac  33300
# 148      dodge  10780
# 149       ford   6700
# 150  chevrolet  20000
# 151   chrysler   6440
# 152       ford  19900
# 153  chevrolet  37000
# 154      dodge   4040
# 155       ford  22300
# ...

# %%
c.groupby("brand").price.mean()
# Out:
# brand
# bmw              37566.666667
# buick            20017.500000
# cadillac         28851.333333
# chevrolet        24665.266667
# chrysler         18332.307692
# dodge             8581.600000
# ford             14645.327586
# gmc              12711.176471
# infiniti         18500.000000
# jeep             17955.555556
# kia              11333.333333
# mercedes-benz    16600.000000
# toyota            6300.000000
# Name: price, dtype: float64

# %%
a=car[car["color"]=="black"]
a
# Out:
#      Unnamed: 0  price      brand     model  year   title_status  mileage  \
# 0             0   6300     toyota   cruiser  2008  clean vehicle   274117
# 6             6   7300  chevrolet        pk  2010  clean vehicle   149050
# 9             9   5250       ford       mpv  2017  clean vehicle    63418
# 12           12  31900  chevrolet      1500  2018  clean vehicle    22909
# 14           14  20700       ford      door  2013  clean vehicle   100757
# 21           21   7300        kia     forte  2018  clean vehicle    38823
# 22           22  15000  chevrolet      door  2015  clean vehicle    61578
# 35           35  11900        gmc      door  2017  clean vehicle    27965
# 44           44  55000       ford       srw  2017  clean vehicle    15273
# 45           45  12520        gmc      door  2017  clean vehicle    28972
# 49           49  54000       ford       srw  2017  clean vehicle    26241
# 62           62  17800  chevrolet      door  2017  clean vehicle    52435
# ...

# %%
a.count
# Out:
# <bound method DataFrame.count of      Unnamed: 0  price      brand     model  year   title_status  mileage  \
# 0             0   6300     toyota   cruiser  2008  clean vehicle   274117
# 6             6   7300  chevrolet        pk  2010  clean vehicle   149050
# 9             9   5250       ford       mpv  2017  clean vehicle    63418
# 12           12  31900  chevrolet      1500  2018  clean vehicle    22909
# 14           14  20700       ford      door  2013  clean vehicle   100757
# 21           21   7300        kia     forte  2018  clean vehicle    38823
# 22           22  15000  chevrolet      door  2015  clean vehicle    61578
# 35           35  11900        gmc      door  2017  clean vehicle    27965
# 44           44  55000       ford       srw  2017  clean vehicle    15273
# 45           45  12520        gmc      door  2017  clean vehicle    28972
# 49           49  54000       ford       srw  2017  clean vehicle    26241
# ...

# %%
b=car[car["year"]==2017]
b
# Out:
#      Unnamed: 0  price      brand     model  year   title_status  mileage  \
# 7             7  13350        gmc      door  2017  clean vehicle    23525
# 9             9   5250       ford       mpv  2017  clean vehicle    63418
# 11           11  12920        gmc       mpv  2017  clean vehicle    39650
# 13           13   5430   chrysler     wagon  2017  clean vehicle   138650
# 15           15  12710        gmc      door  2017  clean vehicle    25747
# 18           18   5210       ford       mpv  2017  clean vehicle    35714
# 20           20  12520        gmc      door  2017  clean vehicle    30114
# 23           23   6180       ford       mpv  2017  clean vehicle    46010
# 25           25  11900        gmc      door  2017  clean vehicle    28040
# 28           28   4190       ford     doors  2017  clean vehicle    44174
# 30           30  12710        gmc      door  2017  clean vehicle    26364
# 33           33   5330       ford       mpv  2017  clean vehicle    37792
# ...

# %%
x=car["brand"]
y=car["price"]
plt.plot(x,y,"g:")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
car.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0  price      brand     model  year   title_status  mileage  \
# 0             0   6300     toyota   cruiser  2008  clean vehicle   274117
# 1             1   2899       ford        se  2011  clean vehicle   190552
# 2             2   5350      dodge       mpv  2018  clean vehicle    39590
# 3             3  25000       ford      door  2014  clean vehicle    64146
# 4             4  27700  chevrolet      1500  2018  clean vehicle     6654
# 5             5   5700      dodge       mpv  2018  clean vehicle    45561
# 6             6   7300  chevrolet        pk  2010  clean vehicle   149050
# 7             7  13350        gmc      door  2017  clean vehicle    23525
# 8             8  14600  chevrolet    malibu  2018  clean vehicle     9371
# 9             9   5250       ford       mpv  2017  clean vehicle    63418
# 10           10  10400      dodge     coupe  2009  clean vehicle   107856
# ...

# %%
car.dublicate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-46510e71b93f> in <module>
# ----> 1 car.dublicate()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dublicate'
