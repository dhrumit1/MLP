# %%
import pandas as pd

# %%
name=["jigar","nikunj","saloni","dhrumit"]
mark=[0.5,0.8,-3,101]
a=pd.Series(data=name)
a
# Out:
# 0      jigar
# 1     nikunj
# 2     saloni
# 3    dhrumit
# dtype: object

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
s={"name":name,"mark":mark}
s
# Out:
# {'name': ['jigar', 'nikunj', 'saloni', 'dhrumit'], 'mark': [0.5, 0.8, -3, 101]}

# %%
type(s)
# Out:
# dict

# %%
b=pd.Series(data=name,index=["a","x","y","w"])
b
# Out:
# a      jigar
# x     nikunj
# y     saloni
# w    dhrumit
# dtype: object

# %%
c=pd.Series(data=name,index=[1,2,3,4])
c
# Out:
# 1      jigar
# 2     nikunj
# 3     saloni
# 4    dhrumit
# dtype: object

# %%
d=pd.DataFrame(data=s,index=["a","b","c","d"])
d
# Out:
#       name   mark
# a    jigar    0.5
# b   nikunj    0.8
# c   saloni   -3.0
# d  dhrumit  101.0

# %%
d.shape
# Out:
# (4, 2)

# %%
d.info
# Out:
# <bound method DataFrame.info of       name   mark
# a    jigar    0.5
# b   nikunj    0.8
# c   saloni   -3.0
# d  dhrumit  101.0>

# %%
d.describe
# Out:
# <bound method NDFrame.describe of       name   mark
# a    jigar    0.5
# b   nikunj    0.8
# c   saloni   -3.0
# d  dhrumit  101.0>

# %%
d.head(2)
# Out:
#      name  mark
# a   jigar   0.5
# b  nikunj   0.8

# %%
d.tail(2)
# Out:
#       name   mark
# c   saloni   -3.0
# d  dhrumit  101.0

# %%
e=pd.read_csv("Movie-Data.csv")
e
# Out:
#      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 7       8                                 Mindhorn
# 8       9                       The Lost City of Z
# 9      10                               Passengers
# 10     11  Fantastic Beasts and Where to Find Them
# 11     12                           Hidden Figures
# 12     13                                Rogue One
# 13     14                                    Moana
# 14     15                                 Colossal
# 15     16                  The Secret Life of Pets
# 16     17                            Hacksaw Ridge
# ...

# %%
e.shape
# Out:
# (1000, 12)

# %%
e.info
# Out:
# <bound method DataFrame.info of      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 7       8                                 Mindhorn
# 8       9                       The Lost City of Z
# 9      10                               Passengers
# 10     11  Fantastic Beasts and Where to Find Them
# 11     12                           Hidden Figures
# 12     13                                Rogue One
# 13     14                                    Moana
# 14     15                                 Colossal
# 15     16                  The Secret Life of Pets
# 16     17                            Hacksaw Ridge
# ...

# %%
e.describe
# Out:
# <bound method NDFrame.describe of      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 7       8                                 Mindhorn
# 8       9                       The Lost City of Z
# 9      10                               Passengers
# 10     11  Fantastic Beasts and Where to Find Them
# 11     12                           Hidden Figures
# 12     13                                Rogue One
# 13     14                                    Moana
# 14     15                                 Colossal
# 15     16                  The Secret Life of Pets
# 16     17                            Hacksaw Ridge
# ...

# %%
e.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
e.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
e.iloc[999,2]
# Out:
# 'Comedy,Family,Fantasy'

# %%
e.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
e["Title"]
# Out:
# 0                      Guardians of the Galaxy
# 1                                   Prometheus
# 2                                        Split
# 3                                         Sing
# 4                                Suicide Squad
# 5                               The Great Wall
# 6                                   La La Land
# 7                                     Mindhorn
# 8                           The Lost City of Z
# 9                                   Passengers
# 10     Fantastic Beasts and Where to Find Them
# 11                              Hidden Figures
# 12                                   Rogue One
# 13                                       Moana
# 14                                    Colossal
# 15                     The Secret Life of Pets
# 16                               Hacksaw Ridge
# 17                                Jason Bourne
# 18                                        Lion
# 19                                     Arrival
# ...

# %%
e.iloc[10:20,2]
# Out:
# 10      Adventure,Family,Fantasy
# 11       Biography,Drama,History
# 12       Action,Adventure,Sci-Fi
# 13    Animation,Adventure,Comedy
# 14           Action,Comedy,Drama
# 15    Animation,Adventure,Comedy
# 16       Biography,Drama,History
# 17               Action,Thriller
# 18               Biography,Drama
# 19          Drama,Mystery,Sci-Fi
# Name: Genre, dtype: object

# %%
e.iloc[10:20,:3]
# Out:
#     Rank                                    Title                       Genre
# 10    11  Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# 11    12                           Hidden Figures     Biography,Drama,History
# 12    13                                Rogue One     Action,Adventure,Sci-Fi
# 13    14                                    Moana  Animation,Adventure,Comedy
# 14    15                                 Colossal         Action,Comedy,Drama
# 15    16                  The Secret Life of Pets  Animation,Adventure,Comedy
# 16    17                            Hacksaw Ridge     Biography,Drama,History
# 17    18                             Jason Bourne             Action,Thriller
# 18    19                                     Lion             Biography,Drama
# 19    20                                  Arrival        Drama,Mystery,Sci-Fi

# %%
e[["Title","Genre"]]
# Out:
#                                        Title                       Genre
# 0                    Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1                                 Prometheus    Adventure,Mystery,Sci-Fi
# 2                                      Split             Horror,Thriller
# 3                                       Sing     Animation,Comedy,Family
# 4                              Suicide Squad    Action,Adventure,Fantasy
# 5                             The Great Wall    Action,Adventure,Fantasy
# 6                                 La La Land          Comedy,Drama,Music
# 7                                   Mindhorn                      Comedy
# 8                         The Lost City of Z  Action,Adventure,Biography
# 9                                 Passengers     Adventure,Drama,Romance
# 10   Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# 11                            Hidden Figures     Biography,Drama,History
# ...

# %%
d["mark2"]=[101,101,101,-10]
d
# Out:
#       name   mark  mark2
# a    jigar    0.5    101
# b   nikunj    0.8    101
# c   saloni   -3.0    101
# d  dhrumit  101.0    -10

# %%
f=pd.read_csv("Movie-Data.csv",index_col="Title")
f
# Out:
#                                          Rank                       Genre  \
# Title
# Guardians of the Galaxy                     1     Action,Adventure,Sci-Fi
# Prometheus                                  2    Adventure,Mystery,Sci-Fi
# Split                                       3             Horror,Thriller
# Sing                                        4     Animation,Comedy,Family
# Suicide Squad                               5    Action,Adventure,Fantasy
# The Great Wall                              6    Action,Adventure,Fantasy
# La La Land                                  7          Comedy,Drama,Music
# Mindhorn                                    8                      Comedy
# The Lost City of Z                          9  Action,Adventure,Biography
# Passengers                                 10     Adventure,Drama,Romance
# Fantastic Beasts and Where to Find Them    11    Adventure,Family,Fantasy
# Hidden Figures                             12     Biography,Drama,History
# ...

# %%
f.isnull().sum()
# Out:
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
e=f["Revenue (Millions)"]
type(e)
# Out:
# pandas.core.series.Series

# %%
h=e.mean()
h
# Out:
# 82.95637614678897

# %%
g=e.median()
g
# Out:
# 47.985

# %%
i=e.mode()
i
# Out:
# 0    0.03
# dtype: float64

# %%
j=f[["Revenue (Millions)"]]
type(j)
# Out:
# pandas.core.frame.DataFrame

# %%
k=f["Metascore"]
k
# Out:
# Title
# Guardians of the Galaxy                    76.0
# Prometheus                                 65.0
# Split                                      62.0
# Sing                                       59.0
# Suicide Squad                              40.0
# The Great Wall                             42.0
# La La Land                                 93.0
# Mindhorn                                   71.0
# The Lost City of Z                         78.0
# Passengers                                 41.0
# Fantastic Beasts and Where to Find Them    66.0
# Hidden Figures                             74.0
# Rogue One                                  65.0
# Moana                                      81.0
# Colossal                                   70.0
# The Secret Life of Pets                    61.0
# Hacksaw Ridge                              71.0
# Jason Bourne                               58.0
# Lion                                       69.0
# ...

# %%
n=k.mean()
n
# Out:
# 58.985042735042626

# %%
k.fillna(n,inplace=True)
k
# Out:
# Title
# Guardians of the Galaxy                    76.000000
# Prometheus                                 65.000000
# Split                                      62.000000
# Sing                                       59.000000
# Suicide Squad                              40.000000
# The Great Wall                             42.000000
# La La Land                                 93.000000
# Mindhorn                                   71.000000
# The Lost City of Z                         78.000000
# Passengers                                 41.000000
# Fantastic Beasts and Where to Find Them    66.000000
# Hidden Figures                             74.000000
# Rogue One                                  65.000000
# Moana                                      81.000000
# Colossal                                   70.000000
# The Secret Life of Pets                    61.000000
# Hacksaw Ridge                              71.000000
# Jason Bourne                               58.000000
# ...

# %%
s=f.iloc[7]
s
# Out:
# Rank                                                                  8
# Genre                                                            Comedy
# Description           A has-been actor best known for playing the ti...
# Director                                                     Sean Foley
# Actors                Essie Davis, Andrea Riseborough, Julian Barrat...
# Year                                                               2016
# Runtime (Minutes)                                                    89
# Rating                                                              6.4
# Votes                                                              2490
# Revenue (Millions)                                                    5
# Metascore                                                            71
# Name: Mindhorn, dtype: object

# %%
o=f.loc["Annie"]
o
# Out:
# Rank                                                                982
# Genre                                               Comedy,Drama,Family
# Description           A foster kid, who lives with her mean foster m...
# Director                                                     Will Gluck
# Actors                Quvenzhané Wallis, Cameron Diaz, Jamie Foxx, R...
# Year                                                               2014
# Runtime (Minutes)                                                   118
# Rating                                                              5.3
# Votes                                                             27312
# Revenue (Millions)                                                85.91
# Metascore                                                            33
# Name: Annie, dtype: object

# %%
f["Rating"]==8.1
# Out:
# Title
# Guardians of the Galaxy                     True
# Prometheus                                 False
# Split                                      False
# Sing                                       False
# Suicide Squad                              False
# The Great Wall                             False
# La La Land                                 False
# Mindhorn                                   False
# The Lost City of Z                         False
# Passengers                                 False
# Fantastic Beasts and Where to Find Them    False
# Hidden Figures                             False
# Rogue One                                  False
# Moana                                      False
# Colossal                                   False
# The Secret Life of Pets                    False
# Hacksaw Ridge                              False
# Jason Bourne                               False
# Lion                                        True
# ...

# %%
f["Director"]=="Ridley Scott"
# Out:
# Title
# Guardians of the Galaxy                    False
# Prometheus                                  True
# Split                                      False
# Sing                                       False
# Suicide Squad                              False
# The Great Wall                             False
# La La Land                                 False
# Mindhorn                                   False
# The Lost City of Z                         False
# Passengers                                 False
# Fantastic Beasts and Where to Find Them    False
# Hidden Figures                             False
# Rogue One                                  False
# Moana                                      False
# Colossal                                   False
# The Secret Life of Pets                    False
# Hacksaw Ridge                              False
# Jason Bourne                               False
# Lion                                       False
# ...

# %%
q=pd.read_csv("Movie-Data.csv")
q
# Out:
#      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 7       8                                 Mindhorn
# 8       9                       The Lost City of Z
# 9      10                               Passengers
# 10     11  Fantastic Beasts and Where to Find Them
# 11     12                           Hidden Figures
# 12     13                                Rogue One
# 13     14                                    Moana
# 14     15                                 Colossal
# 15     16                  The Secret Life of Pets
# 16     17                            Hacksaw Ridge
# ...

# %%
x=q.iloc[6]
x
# Out:
# Rank                                                                  7
# Title                                                        La La Land
# Genre                                                Comedy,Drama,Music
# Description           A jazz pianist falls for an aspiring actress i...
# Director                                                Damien Chazelle
# Actors                Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....
# Year                                                               2016
# Runtime (Minutes)                                                   128
# Rating                                                              8.3
# Votes                                                            258682
# Revenue (Millions)                                               151.06
# Metascore                                                            93
# Name: 6, dtype: object

# %%
y=q[(q["Year"]==2013)]
y
# Out:
#      Rank                           Title                       Genre  \
# 82     83         The Wolf of Wall Street      Biography,Comedy,Crime
# 90     91                       Prisoners         Crime,Drama,Mystery
# 111   112                12 Years a Slave     Biography,Drama,History
# 134   135                       Furious 6       Action,Crime,Thriller
# 137   138                The Great Gatsby               Drama,Romance
# 156   157                     Pacific Rim     Action,Adventure,Sci-Fi
# 173   174                             Her        Drama,Romance,Sci-Fi
# 174   175                          Frozen  Animation,Adventure,Comedy
# 213   214                         Old Boy        Action,Drama,Mystery
# 214   215            Thor: The Dark World    Action,Adventure,Fantasy
# 224   225               We're the Millers                Comedy,Crime
# 239   240                        The Host    Action,Adventure,Romance
# ...

# %%
y=b[(b["Year"]>=2005) & (b["Year"]<=2010) & (b["Rating"]>=8) & (b["Revenue (Millions)"]<b["Revenue (Millions)"].quantile(0.25))]
y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3123             try:
# -> 3124                 return libindex.get_value_box(s, key)
#    3125             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-6442697c2199> in <module>
# ----> 1 y=b[(b["Year"]>=2005) & (b["Year"]<=2010) & (b["Rating"]>=8) & (b["Revenue (Millions)"]<b["Revenue (Millions)"].quantile(0.25))]
#       2 y
#
# ...
