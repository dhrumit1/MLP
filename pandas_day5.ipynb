# %%
import pandas as pd

# %%
a=pd.read_csv("Movie-Data.csv")
a
# Out:
#      Rank                                    Title  \
# 0       1                  Guardians of the Galaxy
# 1       2                               Prometheus
# 2       3                                    Split
# 3       4                                     Sing
# 4       5                            Suicide Squad
# 5       6                           The Great Wall
# 6       7                               La La Land
# 7       8                                 Mindhorn
# 8       9                       The Lost City of Z
# 9      10                               Passengers
# 10     11  Fantastic Beasts and Where to Find Them
# 11     12                           Hidden Figures
# 12     13                                Rogue One
# 13     14                                    Moana
# 14     15                                 Colossal
# 15     16                  The Secret Life of Pets
# 16     17                            Hacksaw Ridge
# ...

# %%
b=pd.read_csv("Movie-Data.csv",index_col="Title")
b
# Out:
#                                          Rank                       Genre  \
# Title
# Guardians of the Galaxy                     1     Action,Adventure,Sci-Fi
# Prometheus                                  2    Adventure,Mystery,Sci-Fi
# Split                                       3             Horror,Thriller
# Sing                                        4     Animation,Comedy,Family
# Suicide Squad                               5    Action,Adventure,Fantasy
# The Great Wall                              6    Action,Adventure,Fantasy
# La La Land                                  7          Comedy,Drama,Music
# Mindhorn                                    8                      Comedy
# The Lost City of Z                          9  Action,Adventure,Biography
# Passengers                                 10     Adventure,Drama,Romance
# Fantastic Beasts and Where to Find Them    11    Adventure,Family,Fantasy
# Hidden Figures                             12     Biography,Drama,History
# ...

# %%
c=b.loc["Lion"]
c
# Out:
# Rank                                                                 19
# Genre                                                   Biography,Drama
# Description           A five-year-old Indian boy gets lost on the st...
# Director                                                    Garth Davis
# Actors                Dev Patel, Nicole Kidman, Rooney Mara, Sunny P...
# Year                                                               2016
# Runtime (Minutes)                                                   118
# Rating                                                              8.1
# Votes                                                            102061
# Revenue (Millions)                                                51.69
# Metascore                                                            69
# Name: Lion, dtype: object

# %%
b["Year"]
# Out:
# Title
# Guardians of the Galaxy                    2014
# Prometheus                                 2012
# Split                                      2016
# Sing                                       2016
# Suicide Squad                              2016
# The Great Wall                             2016
# La La Land                                 2016
# Mindhorn                                   2016
# The Lost City of Z                         2016
# Passengers                                 2016
# Fantastic Beasts and Where to Find Them    2016
# Hidden Figures                             2016
# Rogue One                                  2016
# Moana                                      2016
# Colossal                                   2016
# The Secret Life of Pets                    2016
# Hacksaw Ridge                              2016
# Jason Bourne                               2016
# Lion                                       2016
# ...

# %%
b["Year"]==2012
# Out:
# Title
# Guardians of the Galaxy                    False
# Prometheus                                  True
# Split                                      False
# Sing                                       False
# Suicide Squad                              False
# The Great Wall                             False
# La La Land                                 False
# Mindhorn                                   False
# The Lost City of Z                         False
# Passengers                                 False
# Fantastic Beasts and Where to Find Them    False
# Hidden Figures                             False
# Rogue One                                  False
# Moana                                      False
# Colossal                                   False
# The Secret Life of Pets                    False
# Hacksaw Ridge                              False
# Jason Bourne                               False
# Lion                                       False
# ...

# %%
data=b[(b["Year"]==2012)]
data
# Out:
#                                            Rank                       Genre  \
# Title
# Prometheus                                    2    Adventure,Mystery,Sci-Fi
# The Avengers                                 77               Action,Sci-Fi
# The Dark Knight Rises                       125             Action,Thriller
# The Place Beyond the Pines                  136        Crime,Drama,Thriller
# Django Unchained                            145               Drama,Western
# The Hunger Games                            152   Adventure,Sci-Fi,Thriller
# Spring Breakers                             212                       Drama
# The Perks of Being a Wallflower             236               Drama,Romance
# Les Misérables                              246       Drama,Musical,Romance
# Battleship                                  257     Action,Adventure,Sci-Fi
# Cloud Atlas                                 268                Drama,Sci-Fi
# ...

# %%
d=b[(b["Director"]=="Ridley Scott")]
d
# Out:
#                         Rank                     Genre  \
# Title
# Prometheus                 2  Adventure,Mystery,Sci-Fi
# The Martian              103    Adventure,Drama,Sci-Fi
# Robin Hood               388    Action,Adventure,Drama
# American Gangster        471     Biography,Crime,Drama
# Exodus: Gods and Kings   517    Action,Adventure,Drama
# The Counselor            522      Crime,Drama,Thriller
# A Good Year              531      Comedy,Drama,Romance
# Body of Lies             738      Action,Drama,Romance
#
#                                                               Description  \
# Title
# Prometheus              Following clues to the origin of mankind, a te...
# The Martian             An astronaut becomes stranded on Mars after hi...
# Robin Hood              In 12th century England, Robin and his band of...
# American Gangster       In 1970s America, a detective works to bring d...
# Exodus: Gods and Kings  The defiant leader Moses rises up against the ...
# ...

# %%
e=b[(b["Year"]>2012)]
e
# Out:
#                                          Rank                       Genre  \
# Title
# Guardians of the Galaxy                     1     Action,Adventure,Sci-Fi
# Split                                       3             Horror,Thriller
# Sing                                        4     Animation,Comedy,Family
# Suicide Squad                               5    Action,Adventure,Fantasy
# The Great Wall                              6    Action,Adventure,Fantasy
# La La Land                                  7          Comedy,Drama,Music
# Mindhorn                                    8                      Comedy
# The Lost City of Z                          9  Action,Adventure,Biography
# Passengers                                 10     Adventure,Drama,Romance
# Fantastic Beasts and Where to Find Them    11    Adventure,Family,Fantasy
# Hidden Figures                             12     Biography,Drama,History
# Rogue One                                  13     Action,Adventure,Sci-Fi
# ...

# %%
f=b[(b["Year"]>=2012) & (b["Year"]<=2016)]
f
# Out:
#                                          Rank                       Genre  \
# Title
# Guardians of the Galaxy                     1     Action,Adventure,Sci-Fi
# Prometheus                                  2    Adventure,Mystery,Sci-Fi
# Split                                       3             Horror,Thriller
# Sing                                        4     Animation,Comedy,Family
# Suicide Squad                               5    Action,Adventure,Fantasy
# The Great Wall                              6    Action,Adventure,Fantasy
# La La Land                                  7          Comedy,Drama,Music
# Mindhorn                                    8                      Comedy
# The Lost City of Z                          9  Action,Adventure,Biography
# Passengers                                 10     Adventure,Drama,Romance
# Fantastic Beasts and Where to Find Them    11    Adventure,Family,Fantasy
# Hidden Figures                             12     Biography,Drama,History
# ...

# %%
g=b[(b["Year"]>=2012) & (b["Year"]<=2016)].head(3)
g
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
#
#                                    Director  \
# Title
# Guardians of the Galaxy          James Gunn
# Prometheus                     Ridley Scott
# Split                    M. Night Shyamalan
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# ...

# %%
h=b[(b["Year"]>=2012) & (b["Year"]<=2018) & (b["Rating"]>=8)]
h
# Out:
#                                             Rank                       Genre  \
# Title
# Guardians of the Galaxy                        1     Action,Adventure,Sci-Fi
# La La Land                                     7          Comedy,Drama,Music
# Hacksaw Ridge                                 17     Biography,Drama,History
# Lion                                          19             Biography,Drama
# Arrival                                       20        Drama,Mystery,Sci-Fi
# Bahubali: The Beginning                       27      Action,Adventure,Drama
# Deadpool                                      34     Action,Adventure,Comedy
# Interstellar                                  37      Adventure,Drama,Sci-Fi
# Star Wars: Episode VII - The Force Awakens    51    Action,Adventure,Fantasy
# Mad Max: Fury Road                            68     Action,Adventure,Sci-Fi
# Zootopia                                      75  Animation,Adventure,Comedy
# ...

# %%
i=b[(b["Year"]>=2012) | (b["Rating"]>8)]
i
# Out:
#                                          Rank                       Genre  \
# Title
# Guardians of the Galaxy                     1     Action,Adventure,Sci-Fi
# Prometheus                                  2    Adventure,Mystery,Sci-Fi
# Split                                       3             Horror,Thriller
# Sing                                        4     Animation,Comedy,Family
# Suicide Squad                               5    Action,Adventure,Fantasy
# The Great Wall                              6    Action,Adventure,Fantasy
# La La Land                                  7          Comedy,Drama,Music
# Mindhorn                                    8                      Comedy
# The Lost City of Z                          9  Action,Adventure,Biography
# Passengers                                 10     Adventure,Drama,Romance
# Fantastic Beasts and Where to Find Them    11    Adventure,Family,Fantasy
# Hidden Figures                             12     Biography,Drama,History
# ...

# %%
j=b[(b["Year"]>=2005) & (b["Year"]<=2010) & (b["Rating"]>=8) & (b["Revenue (Millions)"]<b["Revenue (Millions)"].quantile(0.25))]
j
# Out:
#                      Rank               Genre  \
# Title
# 3 Idiots              431        Comedy,Drama
# The Lives of Others   477      Drama,Thriller
# Incendies             714   Drama,Mystery,War
# Taare Zameen Par      992  Drama,Family,Music
#
#                                                            Description  \
# Title
# 3 Idiots             Two friends are searching for their long lost ...
# The Lives of Others  In 1984 East Berlin, an agent of the secret po...
# Incendies            Twins journey to the Middle East to discover t...
# Taare Zameen Par     An eight-year-old boy is thought to be a lazy ...
#
#                                              Director  \
# Title
# 3 Idiots                              Rajkumar Hirani
# The Lives of Others  Florian Henckel von Donnersmarck
# Incendies                            Denis Villeneuve
# Taare Zameen Par                           Aamir Khan
#
# ...
